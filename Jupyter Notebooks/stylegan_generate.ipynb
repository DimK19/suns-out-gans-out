# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==1.8.1 torchvision==0.9.1
# !pip install ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 804.1 MB 2.6 kB/s
# ...
#      |████████████████████████████████| 17.4 MB 704 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# ...

# %%
# Build the command and run it
SOURCE = "/content/drive/My\ Drive/Colab\ Notebooks/Health/stylegan2-pytorch/stylegan2-ada-pytorch/generate.py"
OUTDIR = "/content/drive/My\ Drive/Colab\ Notebooks/Health/testoutdir"
PICKLE_PATH = "/content/drive/My\ Drive/Colab\ Notebooks/Health/torch_EXPERIMENTS/00000-fkntorch-auto1/network-snapshot-000120.pkl"
cmd = f"python3 {SOURCE} --outdir={OUTDIR} --seeds=85,265,297,849 --network={PICKLE_PATH}"
# !{cmd}
# Out:
# Loading networks from "/content/drive/My Drive/Colab Notebooks/Health/torch_EXPERIMENTS/00000-fkntorch-auto1/network-snapshot-000120.pkl"...
# Generating image for seed 85 (0/4) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Traceback (most recent call last):
#   File "/content/drive/My Drive/Colab Notebooks/Health/stylegan2-pytorch/stylegan2-ada-pytorch/generate.py", line 127, in <module>
#     generate_images() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 610, in invoke
# ...

# %% [markdown]
# **SOLUTION**
#
# https://pillow.readthedocs.io/en/stable/reference/Image.html#PIL.Image.fromarray
# https://pillow.readthedocs.io/en/stable/handbook/concepts.html#concept-modes
#
# In `generate.py` line 121 change `'RGB'` to `'L'` and reshape `img[0].cpu().numpy()` with `reshape(128, 128)` (or whatever dimension the original images have been processed to before training).
#
# `img[0].cpu().numpy().shape` $→$ `(256, 256, 1)`

# %%
# Build the command and run it
SOURCE = "/content/drive/My\ Drive/Colab\ Notebooks/Health/stylegan2-pytorch/stylegan2-ada-pytorch/generate.py"
OUTDIR = "/content/drive/My\ Drive/Colab\ Notebooks/Health/outdir_mal"
PICKLE_PATH = "/content/drive/My\ Drive/Colab\ Notebooks/Health/torch_res_m256/00000-torch_data_malignant_256-auto1/network-snapshot-000080.pkl"
cmd = f"python3 {SOURCE} --outdir={OUTDIR} --seeds=1-200 --network={PICKLE_PATH}"
# !{cmd}
# Out:
# Loading networks from "/content/drive/My Drive/Colab Notebooks/Health/torch_res_m256/00000-torch_data_malignant_256-auto1/network-snapshot-000080.pkl"...
# Generating image for seed 1 (0/200) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 2 (1/200) ...
# Generating image for seed 3 (2/200) ...
# Generating image for seed 4 (3/200) ...
# Generating image for seed 5 (4/200) ...
# Generating image for seed 6 (5/200) ...
# Generating image for seed 7 (6/200) ...
# Generating image for seed 8 (7/200) ...
# Generating image for seed 9 (8/200) ...
# Generating image for seed 10 (9/200) ...
# Generating image for seed 11 (10/200) ...
# Generating image for seed 12 (11/200) ...
# Generating image for seed 13 (12/200) ...
# Generating image for seed 14 (13/200) ...
# Generating image for seed 15 (14/200) ...
# Generating image for seed 16 (15/200) ...
# Generating image for seed 17 (16/200) ...
# ...

# %%
# Build the command and run it
SOURCE = "/content/drive/My\ Drive/Colab\ Notebooks/Health/stylegan2-pytorch/stylegan2-ada-pytorch/generate.py"
OUTDIR = "/content/drive/My\ Drive/Colab\ Notebooks/Health/testoutdir"
PICKLE_PATH = "/content/drive/My\ Drive/Colab\ Notebooks/Health/torch_EXPERIMENTS/00000-fkntorch-auto1/network-snapshot-000120.pkl"
cmd = f"python3 {SOURCE} --outdir={OUTDIR} --seeds=85,265,297,849 --network={PICKLE_PATH}"
# !{cmd}
# Out:
# Loading networks from "/content/drive/My Drive/Colab Notebooks/Health/torch_EXPERIMENTS/00000-fkntorch-auto1/network-snapshot-000120.pkl"...
# Generating image for seed 85 (0/4) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 265 (1/4) ...
# Generating image for seed 297 (2/4) ...
# Generating image for seed 849 (3/4) ...

# %%
# Build the command and run it
SOURCE = "/content/drive/My\ Drive/Colab\ Notebooks/Health/stylegan2-pytorch/stylegan2-ada-pytorch/generate.py"
OUTDIR = "/content/drive/My\ Drive/Colab\ Notebooks/Health/testoutdir"
PICKLE_PATH = "/content/drive/My\ Drive/Colab\ Notebooks/Health/torch_EXPERIMENTS/00000-fkntorch-auto1/network-snapshot-000120.pkl"
cmd = f"python3 {SOURCE} --outdir={OUTDIR} --seeds=1-20 --network={PICKLE_PATH}"
# !{cmd}
# Out:
# Loading networks from "/content/drive/My Drive/Colab Notebooks/Health/torch_EXPERIMENTS/00000-fkntorch-auto1/network-snapshot-000120.pkl"...
# Generating image for seed 1 (0/20) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 2 (1/20) ...
# Generating image for seed 3 (2/20) ...
# Generating image for seed 4 (3/20) ...
# Generating image for seed 5 (4/20) ...
# Generating image for seed 6 (5/20) ...
# Generating image for seed 7 (6/20) ...
# Generating image for seed 8 (7/20) ...
# Generating image for seed 9 (8/20) ...
# Generating image for seed 10 (9/20) ...
# Generating image for seed 11 (10/20) ...
# Generating image for seed 12 (11/20) ...
# Generating image for seed 13 (12/20) ...
# Generating image for seed 14 (13/20) ...
# Generating image for seed 15 (14/20) ...
# Generating image for seed 16 (15/20) ...
# Generating image for seed 17 (16/20) ...
# ...
